# %% [raw]
# This code detects the location of starting point of an office;
#
# Input: List of offices + Corresponding offices
#
# => Output: List of offices with coordinate information

# %%
import pandas as pd
import os
import cv2
import numpy as np
import json

# %%
def Detect_Office(Json,Office):

    NewList=Json['fields']
    Dict=list()
    for d in NewList:
        try:
            newDict={}
            newDict['inferText']=d['inferText']
            newDict['boundingPoly']=d['boundingPoly']
            Dict.append(newDict)
        except KeyError:
            continue

    res = [d
       for d in Dict 
       if (Office[0] == '○') or (Office[0] == d['inferText']) or (Office == d['inferText']) or (Office[-2:][0] == d['inferText'])]

    if len(res)!=0:
        res = res[0]['boundingPoly']['vertices']
        Edge=max(int(d['x']) for d in res)
        return(Edge)
    else:
        return(None)

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

### CLOVA FUNCTION ###
import requests
import uuid
import time
import json
import cv2
import base64

api_url = 'https://deelieyxuc.apigw.ntruss.com/custom/v1/1972/ebd01bcbf693d069817622e9839e20914143c7d0d8953eddee40e8b0af96c95b/general'
secret_key = 'S1NmVXpYZlJ0cGJ0ZEFRZXVlbkRkaHFReE9FcHNTQ0U='

def Clova(Year,Page):
    path="C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\"+Year+"\\"
    with open(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg",'rb') as f:
         file_data = f.read()

    request_json = {
            'images': [
                {
                    'format': 'jpg',
                    'name': 'demo',
                    'data':base64.b64encode(file_data).decode()}],
            'requestId': str(uuid.uuid4()),
            'version': 'V2',
            'timestamp': int(round(time.time() * 1000)),
            'lang':'ja'
            }
    payload = json.dumps(request_json).encode("UTF-8")
    headers = {'X-OCR-SECRET': secret_key,
              'Content-Type': 'application/json'}
    response = requests.request("POST", api_url, headers=headers, data = payload)
    Json=json.loads(response.text)['images'][0]
    
    return Json

# %%
Year='1938'
Showa='13'
path="C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\"+Year+"\\"
os.chdir(path)
df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())

# %%
n=0
Row  = df.iloc[n]
Page=int(Row["Page"])
Office=Row["Office"]
Dept=Row['Dept']
print(Office,Dept)
dta[Year][Dept][Office]={}
dta[Year][Dept][Office]["Starting_Page"]=Page

img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
#Convert to json via CLOVA
Json=Clova(Year,Page)

#Find X coordinate of 'Office'.
XCoord_Unit=Detect_Office(Json,Office)
dta[str(Year)][Dept][Office]["Office_X1"]=XCoord_Unit
HH=img.shape[:2][0]
print(Office+ 'success')
cv2.line(img, (XCoord_Unit,0), (XCoord_Unit,HH), (255,0,0), 2)
cv2.imshow('pic',img)
cv2.waitKey(0)
# Out:
# 秘書課 Admin
# 秘書課success
# -1

# %%
#Test code| Version 2#
#Show Working office#
FailedList=[]
for n in range(1,len(df)):
    #Extract key info of office
    Row  = df.iloc[n]
    ExRow= df.iloc[n-1]

    Page=int(Row["Page"])
    Office=Row["Office"]
    Dept=Row['Dept']

    ExPage=int(ExRow["Page"])
    ExOffice=ExRow["Office"]
    ExDept=ExRow['Dept']

    ###Insert Starting page information to motherframe###
    dta[Year][Dept][Office]={}
    dta[Year][Dept][Office]["Starting_Page"]=Page
    print(dta[Year][Dept][Office])

    ###Collect Location information###
    ##Read image for first page##
    img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
    #Convert to json via CLOVA
    Json=Clova(Year,Page)

    #Find X coordinate of 'Office'.
    XCoord_Unit=Detect_Office(Json,Office)
    if XCoord_Unit==None:
        #Add to motherframe
        dta[str(Year)][Dept][Office]["Office_X1"]='NA'
        dta[str(Year)][ExDept][ExOffice]["Ending_Page"]='NA'
        dta[str(Year)][ExDept][ExOffice]["Office_X2"]='NA'
        dta[str(Year)][ExDept][ExOffice]["Page_Range"]='NA'
        print(Office+ 'failed')
        FailedList.append(list((Dept,Office)))
        continue
    else:
        dta[str(Year)][Dept][Office]["Office_X1"]=XCoord_Unit
        dta[str(Year)][ExDept][ExOffice]["Ending_Page"]=Page
        dta[str(Year)][ExDept][ExOffice]["Office_X2"]=XCoord_Unit+10
        dta[str(Year)][ExDept][ExOffice]["Page_Range"]=list(range(ExPage,Page+1))       
        HH=img.shape[:2][0]
        print(Office+ 'success')
        cv2.line(img, (XCoord_Unit,0), (XCoord_Unit,HH), (255,0,0), 2)
        cv2.imshow('pic',img)
        cv2.waitKey(0)
# Out:
# {'Starting_Page': 2}
# 人事課success
# {'Starting_Page': 4}
# 文書課success
# {'Starting_Page': 6}
# 庶務課success
# {'Starting_Page': 7}
# 企画課success
# {'Starting_Page': 8}
# 財務課success
# {'Starting_Page': 9}
# 統計課success
# {'Starting_Page': 20}
# 都市計画課failed
# {'Starting_Page': 24}
# 会計課success
# {'Starting_Page': 26}
# 公債課success
# {'Starting_Page': 27}
# 主税課success
# {'Starting_Page': 34}
# 徴収課failed
# {'Starting_Page': 39}
# 用度課success
# {'Starting_Page': 43}
# 地理課success
# {'Starting_Page': 48}
# 庶務課success
# {'Starting_Page': 49}
# 商工課success
# {'Starting_Page': 52}
# 貿易課success
# {'Starting_Page': 53}
# 出張所failed
# {'Starting_Page': 54}
# 農漁課success
# {'Starting_Page': 56}
# 権度課success
# {'Starting_Page': 57}
# 庶務課success
# {'Starting_Page': 58}
# 学務課success
# {'Starting_Page': 60}
# 社会教育課failed
# {'Starting_Page': 66}
# 体育課success
# {'Starting_Page': 69}
# 視学課failed
# {'Starting_Page': 75}
# 庶務課failed
# {'Starting_Page': 76}
# 保護課success
# {'Starting_Page': 90}
# 福利課success
# {'Starting_Page': 94}
# 職業課success
# {'Starting_Page': 101}
# 庶務課success
# {'Starting_Page': 102}
# 衛生課success
# {'Starting_Page': 116}
# 公園課failed
# {'Starting_Page': 122}
# 庶務課success
# {'Starting_Page': 126}
# 会計課failed
# {'Starting_Page': 127}
# 業務課success
# {'Starting_Page': 151}
# 給水課success
# {'Starting_Page': 156}
# 拡張課success
# {'Starting_Page': 162}
# 下水課success
# {'Starting_Page': 171}
# 庶務課success
# {'Starting_Page': 173}
# 道路管理課failed
# {'Starting_Page': 177}
# 道路建設課success
# {'Starting_Page': 181}
# 河川課success
# {'Starting_Page': 199}
# 総務課success
# {'Starting_Page': 201}
# 労働課success
# {'Starting_Page': 203}
# 経理課success
# {'Starting_Page': 205}
# 会計課success
# {'Starting_Page': 208}
# 庶務課success
# {'Starting_Page': 209}
# 業務課success
# {'Starting_Page': 212}
# 事業普及課success
# {'Starting_Page': 213}
# 車輌課success
# {'Starting_Page': 216}
# 保線課success
# {'Starting_Page': 219}
# 交通統制調査課success
# {'Starting_Page': 241}
# 営業課success
# {'Starting_Page': 244}
# 配線課success
# {'Starting_Page': 246}
# 電力課success
# {'Starting_Page': 260}
# 監察部success
# {'Starting_Page': 262}
# 区政部success
# {'Starting_Page': 264}
# 国民総精神総動員課failed
# {'Starting_Page': 265}
# 防衛課success
# {'Starting_Page': 267}
# 軍事援護課success
# {'Starting_Page': 268}
# 監察課success
# {'Starting_Page': 273}
# 作業課success
# {'Starting_Page': 283}
# 庶務課success
# {'Starting_Page': 284}
# 技術課success
# {'Starting_Page': 286}
# 地所課success
# {'Starting_Page': 287}
# 港務課failed
# {'Starting_Page': 289}
# 監理課success
# {'Starting_Page': 293}
# 会計課success
# {'Starting_Page': 294}
# 庶務課success
# {'Starting_Page': 295}
# 監護課success
# {'Starting_Page': 296}
# 医務課success
# {'Starting_Page': 299}
# 会計課success
# {'Starting_Page': 300}
# 巣鴨分院success
# {'Starting_Page': 300}
# 安房分院success
# {'Starting_Page': 301}
# 井之頭学校failed
# {'Starting_Page': 302}
# 庶務課success
# {'Starting_Page': 303}
# 試験課success
# {'Starting_Page': 303}
# 研究課success
# {'Starting_Page': 305}
# 庶務課success
# {'Starting_Page': 306}
# 工事課success
# {'Starting_Page': 309}
# 管理課success
# {'Starting_Page': 311}
# 第一工菅課failed
# {'Starting_Page': 313}
# 第二工菅課failed
# {'Starting_Page': 314}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Temp\ipykernel_28128\1706092455.py in <module>
#      24     img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
#      25     #Convert to json via CLOVA
# ---> 26     Json=Clova(Year,Page)
#      27
#      28     #Find X coordinate of 'Office'.
#
# C:\Temp\ipykernel_28128\86052506.py in Clova(Year, Page)
#      46 def Clova(Year,Page):
#      47     path="C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\"+Year+"\\"
# ---> 48     with open(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg",'rb') as f:
#      49          file_data = f.read()
#      50
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\1938\\Page314\\Page314.jpg'

# %%
if len(FailedList)/len(df)<0.2:
    print('Fantastic!! Success Rate is '+str(1-(len(FailedList)/len(df))))
else:
    print('残念...Success Rate is '+str(1-(len(FailedList)/len(df))))
# Out:
# Fantastic!! Success Rate is 0.8333333333333334

# %%
#Fixing Failed Offices
#Step1: Check for simple page assignment error
path="C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\"+Year+"\\"
for n in range(2,len(FailedList)):
    Dept=FailedList[n][0]
    Office=FailedList[n][1]
    print(Dept,Office)
    Page=df['Page'][(df['Office']==Office) & (df['Dept']==Dept)].tolist()[0]
    image=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
    cv2.imshow('Image',image)
    cv2.waitKey(0)
# Out:
# 産業局 出張所
# 教育局 社会教育課
# 教育局 視学課
# 社会局 庶務課
# 保健局 公園課
# 水道局 会計課
# 土木局 道路管理課
# 市民動員部 国民総精神総動員課
# 港湾部 港務課
# 養育院 井之頭学校
# 臨時建築部 第一工菅課
# 臨時建築部 第二工菅課

# %%
json_object = json.dumps(dta, indent=4,
                        cls=NpEncoder)
save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+str(Year)+'\\'
with open(save_path+"DataFrame.json", "w") as outfile:
    outfile.write(json_object)

# %%
 dta[Year]
# Out:
# {'Admin': {'秘書課': {'Starting_Page': 2,
#    'Office_X1': 480,
#    'Ending_Page': 2,
#    'Office_X2': 178,
#    'Page_Range': [2]},
#   '人事課': {'Starting_Page': 2,
#    'Office_X1': 168,
#    'Ending_Page': 4,
#    'Office_X2': 377,
#    'Page_Range': [2, 3, 4]},
#   '文書課': {'Starting_Page': 4, 'Office_X1': 367}},
#  '中央卸売市場': {},
#  '企画局（S12.12.18）': {},
#  '保健局': {},
#  '土木局': {},
#  '小河内貯水池建設事務所': {},
#  '市民動員部': {},
#  '教育局': {},
#  '水道局': {},
#  '清掃部': {},
#  '港湾部': {},
#  '産業局': {},
#  '監査部': {},
#  '社会局': {},
#  '経理局（S12.12.18）': {},
#  '臨時建築部': {},
#  '運輸部': {},
#  '電気局': {},
#  '電気研究所': {},
#  '電燈部': {},
#  '養育院': {}}

# %%
#Test code| Version 2#
#Decompose info into elements
Page=int(Row["Page"])
Office=Row["Office"]
print(Office)
ExPage=int(ExRow["Page"])
ExOffice=ExRow["Office"]


###Insert Starting page information to motherframe###
dta[Year][Dept][Office]={}
dta[Year][Dept][Office]["Starting_Page"]=Page
print(dta)

###Collect Location information###
##Read image for first page##
img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
#Convert to json via CLOVA
Json=Clova(Year,Page)

#Find X coordinate of 'Office'.
XCoord_Unit=Detect_Office(Json,Office)
#Add to motherframe
dta[str(Year)][Dept][Office]["Office_X1"]=XCoord_Unit
dta[str(Year)][ExDept][ExOffice]["Ending_Page"]=Page
dta[str(Year)][ExDept][ExOffice]["Office_X2"]=XCoord_Unit+10
dta[str(Year)][ExDept][ExOffice]["Page_Range"]=list(range(ExPage,Page+1))
dta[str(Year)][Dept]
# Out:
# 文書課
# {'1934': {'Admin': {'文書課': {'Starting_Page': 3}, '職員課': {'Starting_Page': 2}, '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]}, '監察課': {'Starting_Page': 5, 'Office_X1': 150}}, '中央卸売市場': {}, '保健局': {}, '土木局': {}, '教育局': {}, '水道局': {}, '港湾部（S8.11.1）': {}, '産業局': {}, '監査局': {'庶務課': {'Starting_Page': 5, 'Office_X1': 429}, '監察課': {'Starting_Page': 5, 'Office_X1': 150}}, '社会局': {}, '財務局': {}, '電気局(S8.11.6)': {}, '電気研究所（S8.11.18）': {}}}
# {'文書課': {'Starting_Page': 3, 'Office_X1': 292},
#  '職員課': {'Starting_Page': 2,
#   'Ending_Page': 3,
#   'Office_X2': 302,
#   'Page_Range': [2, 3]},
#  '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]},
#  '監察課': {'Starting_Page': 5, 'Office_X1': 150}}

# %%
#Test code| Version 2#
#Show Working office#
n=3

#Extract key info of office
Row  = df.iloc[n]
ExRow= df.iloc[n-1]
Row
# Out:
# Office    庶務課
# Dept      監査局
# Year        9
# Page        5
# Name: 3, dtype: object

# %%
Page=int(Row["Page"])
Dept=Row["Dept"]
Office=Row["Office"]
print(Office)
ExPage=int(ExRow["Page"])
ExDept=ExRow["Dept"]
ExOffice=ExRow["Office"]


###Insert Starting page information to motherframe###
dta[Year][Dept][Office]={}
dta[Year][Dept][Office]["Starting_Page"]=Page
print(dta)

###Collect Location information###
##Read image for first page##
img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
#Convert to json via CLOVA
Json=Clova(Year,Page)

#Find X coordinate of 'Office'.
XCoord_Unit=Detect_Office(Json,Office)
#Add to motherframe
dta[str(Year)][Dept][Office]["Office_X1"]=XCoord_Unit
dta[str(Year)][ExDept][ExOffice]["Ending_Page"]=Page
dta[str(Year)][ExDept][ExOffice]["Office_X2"]=XCoord_Unit+10
dta[str(Year)][ExDept][ExOffice]["Page_Range"]=list(range(ExPage,Page+1))
dta
# Out:
# 庶務課
# {'1934': {'Admin': {'文書課': {'Starting_Page': 3, 'Office_X1': 292, 'Ending_Page': 5, 'Office_X2': 439, 'Page_Range': [3, 4, 5], 'Position': {'Manager': {'XLocation': 261, 'Page': 3, 'EndLocation': 230.0, 'EndPage': 3.0}, 'Leader': {'XLocation': 230, 'Page': 3, 'EndLocation': 469.0, 'EndPage': 4.0}, 'Admin': {'XLocation': 469, 'Page': 4, 'EndLocation': 302.0, 'EndPage': 4.0, 'Data': [{'Name': '淺野元三郎', 'Wage': '幸'}, {'Name': '五人店TE', 'Wage': '月七'}, {'Name': '小川有道', 'Wage': '𠮷'}, {'Name': '志賀漆', 'Wage': 'お'}, {'Name': '京山重長', 'Wage': '1'}, {'Name': '天主任人江博房', 'Wage': '万九和'}, {'Name': '各个長下條装', 'Wage': 'カト'}, {'Name': '和久田賞', 'Wage': '上'}, {'Name': '木村五', 'Wage': 'あや'}, {'Name': '長坂番', 'Wage': '幸'}, {'Name': '宮尾D20', 'Wage': '吉'}, {'Name': '正版 松留', 'Wage': '七七'}, {'Name': '鍜田國信', 'Wage': '七上'}, {'Name': '部見安二郎', 'Wage': 'ス'}, {'Name': '高畑稔', 'Wage': '奉'}, {'Name': '長友英太郎', 'Wage': '円1'}, {'Name': '荒井千', 'Wage': '六上'}, {'Name': 'M成七七郎', 'Wage': '大'}]}, 'Outsource': {'XLocation': 302, 'Page': 4, 'EndLocation': 439.0, 'EndPage': 5.0}}}, '職員課': {'Starting_Page': 2, 'Ending_Page': 3, 'Office_X2': 302, 'Page_Range': [2, 3]}, '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]}, '監察課': {'Starting_Page': 5, 'Office_X1': 150}}, '中央卸売市場': {}, '保健局': {}, '土木局': {}, '教育局': {}, '水道局': {}, '港湾部（S8.11.1）': {}, '産業局': {}, '監査局': {'庶務課': {'Starting_Page': 5}, '監察課': {'Starting_Page': 5, 'Office_X1': 150}}, '社会局': {}, '財務局': {}, '電気局(S8.11.6)': {}, '電気研究所（S8.11.18）': {}}}
# {'1934': {'Admin': {'文書課': {'Starting_Page': 3,
#     'Office_X1': 292,
#     'Ending_Page': 5,
#     'Office_X2': 439,
#     'Page_Range': [3, 4, 5],
#     'Position': {'Manager': {'XLocation': 261,
#       'Page': 3,
#       'EndLocation': 230.0,
#       'EndPage': 3.0},
#      'Leader': {'XLocation': 230,
#       'Page': 3,
#       'EndLocation': 469.0,
#       'EndPage': 4.0},
#      'Admin': {'XLocation': 469,
#       'Page': 4,
#       'EndLocation': 302.0,
#       'EndPage': 4.0,
#       'Data': [{'Name': '淺野元三郎', 'Wage': '幸'},
#        {'Name': '五人店TE', 'Wage': '月七'},
#        {'Name': '小川有道', 'Wage': '𠮷'},
#        {'Name': '志賀漆', 'Wage': 'お'},
#        {'Name': '京山重長', 'Wage': '1'},
#        {'Name': '天主任人江博房', 'Wage': '万九和'},
#        {'Name': '各个長下條装', 'Wage': 'カト'},
#        {'Name': '和久田賞', 'Wage': '上'},
#        {'Name': '木村五', 'Wage': 'あや'},
#        {'Name': '長坂番', 'Wage': '幸'},
#        {'Name': '宮尾D20', 'Wage': '吉'},
#        {'Name': '正版 松留', 'Wage': '七七'},
#        {'Name': '鍜田國信', 'Wage': '七上'},
#        {'Name': '部見安二郎', 'Wage': 'ス'},
#        {'Name': '高畑稔', 'Wage': '奉'},
#        {'Name': '長友英太郎', 'Wage': '円1'},
#        {'Name': '荒井千', 'Wage': '六上'},
#        {'Name': 'M成七七郎', 'Wage': '大'}]},
#      'Outsource': {'XLocation': 302,
#       'Page': 4,
#       'EndLocation': 439.0,
#       'EndPage': 5.0}}},
#    '職員課': {'Starting_Page': 2,
#     'Ending_Page': 3,
#     'Office_X2': 302,
#     'Page_Range': [2, 3]},
#    '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]},
#    '監察課': {'Starting_Page': 5, 'Office_X1': 150}},
#   '中央卸売市場': {},
#   '保健局': {},
#   '土木局': {},
#   '教育局': {},
#   '水道局': {},
#   '港湾部（S8.11.1）': {},
#   '産業局': {},
#   '監査局': {'庶務課': {'Starting_Page': 5, 'Office_X1': 429},
#    '監察課': {'Starting_Page': 5, 'Office_X1': 150}},
#   '社会局': {},
#   '財務局': {},
#   '電気局(S8.11.6)': {},
#   '電気研究所（S8.11.18）': {}}}

# %%
#Test code| Version 2#
#Show Working office#
n=4

#Extract key info of office
Row  = df.iloc[n]
ExRow= df.iloc[n-1]
Row
# Out:
# Office    監察課
# Dept      監査局
# Year        9
# Page        5
# Name: 4, dtype: object

# %%
Page=int(Row["Page"])
Office=Row["Office"]
print(Office)
ExPage=int(ExRow["Page"])
ExOffice=ExRow["Office"]


###Insert Starting page information to motherframe###
dta[Year][Dept][Office]={}
dta[Year][Dept][Office]["Starting_Page"]=Page
print(dta)

###Collect Location information###
##Read image for first page##
img=cv2.imread("Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
#Convert to json via CLOVA
Json=Clova(Year,Page)

#Find X coordinate of 'Office'.
XCoord_Unit=Detect_Office(Json,Office)
#Add to motherframe
dta[str(Year)][Dept][Office]["Office_X1"]=XCoord_Unit
dta[str(Year)][ExDept][ExOffice]["Ending_Page"]=Page
dta[str(Year)][ExDept][ExOffice]["Office_X2"]=XCoord_Unit+10
dta[str(Year)][ExDept][ExOffice]["Page_Range"]=list(range(ExPage,Page+1))
dta
# Out:
# 監察課
# {'1934': {'Admin': {'文書課': {'Starting_Page': 3, 'Office_X1': 292, 'Ending_Page': 5, 'Office_X2': 439, 'Page_Range': [3, 4, 5]}, '職員課': {'Starting_Page': 2, 'Ending_Page': 3, 'Office_X2': 302, 'Page_Range': [2, 3]}, '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]}, '監察課': {'Starting_Page': 5, 'Office_X1': 150}}, '中央卸売市場': {}, '保健局': {}, '土木局': {}, '教育局': {}, '水道局': {}, '港湾部（S8.11.1）': {}, '産業局': {}, '監査局': {'庶務課': {'Starting_Page': 5, 'Office_X1': 429}, '監察課': {'Starting_Page': 5}}, '社会局': {}, '財務局': {}, '電気局(S8.11.6)': {}, '電気研究所（S8.11.18）': {}}}
# {'1934': {'Admin': {'文書課': {'Starting_Page': 3,
#     'Office_X1': 292,
#     'Ending_Page': 5,
#     'Office_X2': 439,
#     'Page_Range': [3, 4, 5]},
#    '職員課': {'Starting_Page': 2,
#     'Ending_Page': 3,
#     'Office_X2': 302,
#     'Page_Range': [2, 3]},
#    '庶務課': {'Ending_Page': 5, 'Office_X2': 160, 'Page_Range': [5]},
#    '監察課': {'Starting_Page': 5, 'Office_X1': 150}},
#   '中央卸売市場': {},
#   '保健局': {},
#   '土木局': {},
#   '教育局': {},
#   '水道局': {},
#   '港湾部（S8.11.1）': {},
#   '産業局': {},
#   '監査局': {'庶務課': {'Starting_Page': 5, 'Office_X1': 429},
#    '監察課': {'Starting_Page': 5, 'Office_X1': 150}},
#   '社会局': {},
#   '財務局': {},
#   '電気局(S8.11.6)': {},
#   '電気研究所（S8.11.18）': {}}}

# %%
Json
# Out:
# {'uid': '7b5fa09153984ed29ce122f72cf353b0',
#  'name': 'demo',
#  'inferResult': 'SUCCESS',
#  'message': 'SUCCESS',
#  'validationResult': {'result': 'NO_REQUESTED'},
#  'convertedImageInfo': {'width': 603,
#   'height': 470,
#   'pageIndex': 0,
#   'longImage': False},
#  'fields': [{'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 480.0, 'y': 69.0},
#      {'x': 480.0, 'y': 103.0},
#      {'x': 461.0, 'y': 103.0},
#      {'x': 461.0, 'y': 69.0}]},
#    'inferText': '○湯',
#    'inferConfidence': 0.7066,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 460.0, 'y': 116.0},
#      {'x': 480.0, 'y': 116.0},
#      {'x': 480.0, 'y': 136.0},
#      {'x': 460.0, 'y': 136.0}]},
#    'inferText': '書',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 459.0, 'y': 149.0},
#      {'x': 478.0, 'y': 149.0},
#      {'x': 478.0, 'y': 167.0},
#      {'x': 459.0, 'y': 167.0}]},
#    'inferText': '課',
#    'inferConfidence': 0.9999,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 458.0, 'y': 179.0},
#      {'x': 468.0, 'y': 179.0},
#      {'x': 467.0, 'y': 201.0},
#      {'x': 457.0, 'y': 201.0}]},
#    'inferText': '密裏',
#    'inferConfidence': 0.5814,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 470.0, 'y': 178.0},
#      {'x': 490.0, 'y': 180.0},
#      {'x': 479.0, 'y': 296.0},
#      {'x': 460.0, 'y': 294.0}]},
#    'inferText': '自動四二一·四三八',
#    'inferConfidence': 0.8469,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 457.0, 'y': 229.0},
#      {'x': 467.0, 'y': 229.0},
#      {'x': 467.0, 'y': 237.0},
#      {'x': 457.0, 'y': 237.0}]},
#    'inferText': '六',
#    'inferConfidence': 0.4155,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 436.0, 'y': 69.0},
#      {'x': 448.0, 'y': 69.0},
#      {'x': 446.0, 'y': 105.0},
#      {'x': 434.0, 'y': 104.0}]},
#    'inferText': '主事四',
#    'inferConfidence': 0.8423,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 431.0, 'y': 269.0},
#      {'x': 446.0, 'y': 269.0},
#      {'x': 446.0, 'y': 308.0},
#      {'x': 431.0, 'y': 308.0}]},
#    'inferText': '課長森',
#    'inferConfidence': 0.9718,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 430.0, 'y': 342.0},
#      {'x': 447.0, 'y': 342.0},
#      {'x': 447.0, 'y': 358.0},
#      {'x': 430.0, 'y': 358.0}]},
#    'inferText': '徹',
#    'inferConfidence': 0.9986,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 430.0, 'y': 376.0},
#      {'x': 446.0, 'y': 376.0},
#      {'x': 446.0, 'y': 392.0},
#      {'x': 430.0, 'y': 392.0}]},
#    'inferText': '夫',
#    'inferConfidence': 0.9988,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 421.0, 'y': 301.0},
#      {'x': 430.0, 'y': 301.0},
#      {'x': 430.0, 'y': 331.0},
#      {'x': 421.0, 'y': 331.0}]},
#    'inferText': '世界谷、',
#    'inferConfidence': 0.9097,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 421.0, 'y': 331.0},
#      {'x': 429.0, 'y': 331.0},
#      {'x': 429.0, 'y': 366.0},
#      {'x': 421.0, 'y': 366.0}]},
#    'inferText': '教科、三日',
#    'inferConfidence': 0.7264,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 413.0, 'y': 303.0},
#      {'x': 421.0, 'y': 303.0},
#      {'x': 420.0, 'y': 366.0},
#      {'x': 412.0, 'y': 366.0}]},
#    'inferText': '信用百四三五九',
#    'inferConfidence': 0.9337,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 402.0, 'y': 68.0},
#      {'x': 410.0, 'y': 68.0},
#      {'x': 410.0, 'y': 76.0},
#      {'x': 402.0, 'y': 76.0}]},
#    'inferText': '九',
#    'inferConfidence': 0.9687,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 402.0, 'y': 76.0},
#      {'x': 411.0, 'y': 76.0},
#      {'x': 411.0, 'y': 85.0},
#      {'x': 402.0, 'y': 85.0}]},
#    'inferText': 'ト',
#    'inferConfidence': 0.7029,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 398.0, 'y': 209.0},
#      {'x': 411.0, 'y': 209.0},
#      {'x': 410.0, 'y': 307.0},
#      {'x': 397.0, 'y': 307.0}]},
#    'inferText': '情報主任正名:動力紫禁',
#    'inferConfidence': 0.7323,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 395.0, 'y': 313.0},
#      {'x': 411.0, 'y': 313.0},
#      {'x': 410.0, 'y': 370.0},
#      {'x': 394.0, 'y': 370.0}]},
#    'inferText': '關左以',
#    'inferConfidence': 0.9934,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 393.0, 'y': 376.0},
#      {'x': 410.0, 'y': 376.0},
#      {'x': 410.0, 'y': 393.0},
#      {'x': 393.0, 'y': 393.0}]},
#    'inferText': '治',
#    'inferConfidence': 0.9973,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 385.0, 'y': 301.0},
#      {'x': 393.0, 'y': 301.0},
#      {'x': 393.0, 'y': 366.0},
#      {'x': 385.0, 'y': 366.0}]},
#    'inferText': '、、',
#    'inferConfidence': 0.7697,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 374.0, 'y': 67.0},
#      {'x': 383.0, 'y': 67.0},
#      {'x': 383.0, 'y': 76.0},
#      {'x': 374.0, 'y': 76.0}]},
#    'inferText': '·',
#    'inferConfidence': 0.3901,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 369.0, 'y': 204.0},
#      {'x': 383.0, 'y': 204.0},
#      {'x': 381.0, 'y': 308.0},
#      {'x': 368.0, 'y': 307.0}]},
#    'inferText': '(人事課勤務)正大恆',
#    'inferConfidence': 0.9068,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 367.0, 'y': 328.0},
#      {'x': 382.0, 'y': 328.0},
#      {'x': 382.0, 'y': 343.0},
#      {'x': 367.0, 'y': 343.0}]},
#    'inferText': '岡',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 367.0, 'y': 377.0},
#      {'x': 382.0, 'y': 377.0},
#      {'x': 382.0, 'y': 391.0},
#      {'x': 367.0, 'y': 391.0}]},
#    'inferText': '恒',
#    'inferConfidence': 0.4974,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 352.0, 'y': 66.0},
#      {'x': 369.0, 'y': 66.0},
#      {'x': 369.0, 'y': 96.0},
#      {'x': 352.0, 'y': 96.0}]},
#    'inferText': '書記',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 340.0, 'y': 68.0},
#      {'x': 348.0, 'y': 68.0},
#      {'x': 348.0, 'y': 76.0},
#      {'x': 340.0, 'y': 76.0}]},
#    'inferText': 'R',
#    'inferConfidence': 0.9532,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 340.0, 'y': 99.0},
#      {'x': 352.0, 'y': 99.0},
#      {'x': 352.0, 'y': 128.0},
#      {'x': 340.0, 'y': 128.0}]},
#    'inferText': 'T',
#    'inferConfidence': 0.0595,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 336.0, 'y': 104.0},
#      {'x': 343.0, 'y': 104.0},
#      {'x': 343.0, 'y': 136.0},
#      {'x': 336.0, 'y': 136.0}]},
#    'inferText': '索罟',
#    'inferConfidence': 0.3428,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 343.0, 'y': 128.0},
#      {'x': 353.0, 'y': 128.0},
#      {'x': 353.0, 'y': 137.0},
#      {'x': 343.0, 'y': 137.0}]},
#    'inferText': '公',
#    'inferConfidence': 0.9997,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 336.0, 'y': 140.0},
#      {'x': 350.0, 'y': 140.0},
#      {'x': 350.0, 'y': 153.0},
#      {'x': 336.0, 'y': 153.0}]},
#    'inferText': '村',
#    'inferConfidence': 0.9996,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 336.0, 'y': 158.0},
#      {'x': 349.0, 'y': 158.0},
#      {'x': 349.0, 'y': 212.0},
#      {'x': 336.0, 'y': 212.0}]},
#    'inferText': '松 竹太郎',
#    'inferConfidence': 0.9373,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 340.0, 'y': 245.0},
#      {'x': 349.0, 'y': 245.0},
#      {'x': 349.0, 'y': 262.0},
#      {'x': 340.0, 'y': 262.0}]},
#    'inferText': '五上',
#    'inferConfidence': 0.9867,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 335.0, 'y': 317.0},
#      {'x': 349.0, 'y': 317.0},
#      {'x': 349.0, 'y': 331.0},
#      {'x': 335.0, 'y': 331.0}]},
#    'inferText': '渡',
#    'inferConfidence': 0.9936,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 335.0, 'y': 341.0},
#      {'x': 348.0, 'y': 341.0},
#      {'x': 348.0, 'y': 354.0},
#      {'x': 335.0, 'y': 354.0}]},
#    'inferText': '邊',
#    'inferConfidence': 0.9559,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 334.0, 'y': 378.0},
#      {'x': 348.0, 'y': 378.0},
#      {'x': 348.0, 'y': 392.0},
#      {'x': 334.0, 'y': 392.0}]},
#    'inferText': '守',
#    'inferConfidence': 0.9992,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 326.0, 'y': 67.0},
#      {'x': 334.0, 'y': 67.0},
#      {'x': 334.0, 'y': 83.0},
#      {'x': 326.0, 'y': 83.0}]},
#    'inferText': '五下',
#    'inferConfidence': 0.9961,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 321.0, 'y': 140.0},
#      {'x': 333.0, 'y': 140.0},
#      {'x': 333.0, 'y': 151.0},
#      {'x': 321.0, 'y': 151.0}]},
#    'inferText': '田',
#    'inferConfidence': 0.9867,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 320.0, 'y': 158.0},
#      {'x': 333.0, 'y': 158.0},
#      {'x': 333.0, 'y': 211.0},
#      {'x': 320.0, 'y': 211.0}]},
#    'inferText': '逢 太太郎',
#    'inferConfidence': 0.8417,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 319.0, 'y': 269.0},
#      {'x': 331.0, 'y': 269.0},
#      {'x': 331.0, 'y': 390.0},
#      {'x': 319.0, 'y': 390.0}]},
#    'inferText': '(大理課税)估石石さだ子',
#    'inferConfidence': 0.6158,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 305.0, 'y': 139.0},
#      {'x': 318.0, 'y': 140.0},
#      {'x': 318.0, 'y': 170.0},
#      {'x': 304.0, 'y': 170.0}]},
#    'inferText': '小坂',
#    'inferConfidence': 0.9973,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 308.0, 'y': 246.0},
#      {'x': 316.0, 'y': 246.0},
#      {'x': 316.0, 'y': 260.0},
#      {'x': 308.0, 'y': 260.0}]},
#    'inferText': 'に',
#    'inferConfidence': 0.4218,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 303.0, 'y': 317.0},
#      {'x': 315.0, 'y': 317.0},
#      {'x': 315.0, 'y': 347.0},
#      {'x': 303.0, 'y': 347.0}]},
#    'inferText': '池田',
#    'inferConfidence': 0.9809,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 301.0, 'y': 360.0},
#      {'x': 315.0, 'y': 360.0},
#      {'x': 316.0, 'y': 391.0},
#      {'x': 302.0, 'y': 392.0}]},
#    'inferText': '正義',
#    'inferConfidence': 0.965,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 310.0, 'y': 67.0},
#      {'x': 317.0, 'y': 67.0},
#      {'x': 317.0, 'y': 90.0},
#      {'x': 310.0, 'y': 90.0}]},
#    'inferText': '月光五',
#    'inferConfidence': 0.9432,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 304.0, 'y': 181.0},
#      {'x': 317.0, 'y': 182.0},
#      {'x': 316.0, 'y': 211.0},
#      {'x': 303.0, 'y': 211.0}]},
#    'inferText': '憲 三',
#    'inferConfidence': 0.8485,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 293.0, 'y': 66.0},
#      {'x': 303.0, 'y': 66.0},
#      {'x': 303.0, 'y': 83.0},
#      {'x': 293.0, 'y': 83.0}]},
#    'inferText': '七上',
#    'inferConfidence': 0.7031,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 289.0, 'y': 139.0},
#      {'x': 302.0, 'y': 139.0},
#      {'x': 301.0, 'y': 211.0},
#      {'x': 287.0, 'y': 211.0}]},
#    'inferText': '井上内蔵之助',
#    'inferConfidence': 0.9597,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 270.0, 'y': 66.0},
#      {'x': 283.0, 'y': 66.0},
#      {'x': 283.0, 'y': 79.0},
#      {'x': 270.0, 'y': 79.0}]},
#    'inferText': '履',
#    'inferConfidence': 0.3049,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 271.0, 'y': 110.0},
#      {'x': 283.0, 'y': 110.0},
#      {'x': 283.0, 'y': 134.0},
#      {'x': 271.0, 'y': 134.0}]},
#    'inferText': '山',
#    'inferConfidence': 0.8855,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 270.0, 'y': 147.0},
#      {'x': 282.0, 'y': 147.0},
#      {'x': 282.0, 'y': 171.0},
#      {'x': 270.0, 'y': 171.0}]},
#    'inferText': '啓子',
#    'inferConfidence': 0.9997,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 272.0, 'y': 188.0},
#      {'x': 280.0, 'y': 188.0},
#      {'x': 280.0, 'y': 195.0},
#      {'x': 272.0, 'y': 195.0}]},
#    'inferText': '24',
#    'inferConfidence': 0.5502,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 270.0, 'y': 219.0},
#      {'x': 283.0, 'y': 220.0},
#      {'x': 281.0, 'y': 244.0},
#      {'x': 268.0, 'y': 243.0}]},
#    'inferText': '及川',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 269.0, 'y': 256.0},
#      {'x': 281.0, 'y': 256.0},
#      {'x': 280.0, 'y': 280.0},
#      {'x': 268.0, 'y': 280.0}]},
#    'inferText': '金男',
#    'inferConfidence': 0.9905,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 267.0, 'y': 328.0},
#      {'x': 282.0, 'y': 328.0},
#      {'x': 282.0, 'y': 355.0},
#      {'x': 267.0, 'y': 355.0}]},
#    'inferText': '新坂',
#    'inferConfidence': 0.9587,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 266.0, 'y': 365.0},
#      {'x': 281.0, 'y': 365.0},
#      {'x': 281.0, 'y': 390.0},
#      {'x': 266.0, 'y': 390.0}]},
#    'inferText': '公三',
#    'inferConfidence': 0.9348,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 255.0, 'y': 110.0},
#      {'x': 267.0, 'y': 110.0},
#      {'x': 267.0, 'y': 134.0},
#      {'x': 255.0, 'y': 134.0}]},
#    'inferText': '落合',
#    'inferConfidence': 0.9999,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 255.0, 'y': 146.0},
#      {'x': 267.0, 'y': 146.0},
#      {'x': 266.0, 'y': 171.0},
#      {'x': 254.0, 'y': 171.0}]},
#    'inferText': '診雄',
#    'inferConfidence': 0.7259,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 253.0, 'y': 219.0},
#      {'x': 267.0, 'y': 219.0},
#      {'x': 267.0, 'y': 243.0},
#      {'x': 253.0, 'y': 243.0}]},
#    'inferText': '栗原',
#    'inferConfidence': 0.9322,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 253.0, 'y': 256.0},
#      {'x': 266.0, 'y': 256.0},
#      {'x': 266.0, 'y': 281.0},
#      {'x': 253.0, 'y': 281.0}]},
#    'inferText': '歌子',
#    'inferConfidence': 0.9999,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 251.0, 'y': 328.0},
#      {'x': 265.0, 'y': 328.0},
#      {'x': 265.0, 'y': 354.0},
#      {'x': 251.0, 'y': 354.0}]},
#    'inferText': '小林',
#    'inferConfidence': 0.9382,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 250.0, 'y': 364.0},
#      {'x': 264.0, 'y': 364.0},
#      {'x': 264.0, 'y': 391.0},
#      {'x': 250.0, 'y': 391.0}]},
#    'inferText': '生活',
#    'inferConfidence': 0.8322,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 232.0, 'y': 374.0},
#      {'x': 249.0, 'y': 374.0},
#      {'x': 249.0, 'y': 391.0},
#      {'x': 232.0, 'y': 391.0}]},
#    'inferText': '郞',
#    'inferConfidence': 0.6441,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 237.0, 'y': 66.0},
#      {'x': 251.0, 'y': 66.0},
#      {'x': 251.0, 'y': 197.0},
#      {'x': 237.0, 'y': 197.0}]},
#    'inferText': '喝采邑市務卿託キ八00',
#    'inferConfidence': 0.4786,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 236.0, 'y': 276.0},
#      {'x': 248.0, 'y': 276.0},
#      {'x': 248.0, 'y': 306.0},
#      {'x': 236.0, 'y': 306.0}]},
#    'inferText': '做工中',
#    'inferConfidence': 0.6402,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 233.0, 'y': 318.0},
#      {'x': 249.0, 'y': 318.0},
#      {'x': 249.0, 'y': 334.0},
#      {'x': 233.0, 'y': 334.0}]},
#    'inferText': '川',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 189.0, 'y': 346.0},
#      {'x': 249.0, 'y': 346.0},
#      {'x': 249.0, 'y': 362.0},
#      {'x': 189.0, 'y': 362.0}]},
#    'inferText': '一重 吉',
#    'inferConfidence': 0.8863,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 225.0, 'y': 299.0},
#      {'x': 234.0, 'y': 299.0},
#      {'x': 232.0, 'y': 329.0},
#      {'x': 224.0, 'y': 328.0}]},
#    'inferText': '中野、道',
#    'inferConfidence': 0.7949,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 223.0, 'y': 327.0},
#      {'x': 233.0, 'y': 327.0},
#      {'x': 233.0, 'y': 336.0},
#      {'x': 223.0, 'y': 336.0}]},
#    'inferText': '8',
#    'inferConfidence': 0.8746,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 223.0, 'y': 336.0},
#      {'x': 233.0, 'y': 336.0},
#      {'x': 233.0, 'y': 345.0},
#      {'x': 223.0, 'y': 345.0}]},
#    'inferText': '円',
#    'inferConfidence': 0.2208,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 223.0, 'y': 343.0},
#      {'x': 233.0, 'y': 343.0},
#      {'x': 233.0, 'y': 353.0},
#      {'x': 223.0, 'y': 353.0}]},
#    'inferText': ',',
#    'inferConfidence': 0.9851,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 171.0, 'y': 174.0},
#      {'x': 225.0, 'y': 185.0},
#      {'x': 221.0, 'y': 206.0},
#      {'x': 167.0, 'y': 195.0}]},
#    'inferText': '隆 織 正',
#    'inferConfidence': 0.8585,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 206.0, 'y': 319.0},
#      {'x': 221.0, 'y': 319.0},
#      {'x': 221.0, 'y': 334.0},
#      {'x': 206.0, 'y': 334.0}]},
#    'inferText': '田',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 186.0, 'y': 374.0},
#      {'x': 222.0, 'y': 374.0},
#      {'x': 222.0, 'y': 391.0},
#      {'x': 186.0, 'y': 391.0}]},
#    'inferText': '雄 装',
#    'inferConfidence': 0.6309,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 189.0, 'y': 156.0},
#      {'x': 223.0, 'y': 157.0},
#      {'x': 223.0, 'y': 173.0},
#      {'x': 189.0, 'y': 172.0}]},
#    'inferText': '川山',
#    'inferConfidence': 0.7687,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 170.0, 'y': 211.0},
#      {'x': 223.0, 'y': 212.0},
#      {'x': 222.0, 'y': 229.0},
#      {'x': 169.0, 'y': 228.0}]},
#    'inferText': '雄三賀',
#    'inferConfidence': 0.9925,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 207.0, 'y': 275.0},
#      {'x': 221.0, 'y': 275.0},
#      {'x': 221.0, 'y': 306.0},
#      {'x': 207.0, 'y': 306.0}]},
#    'inferText': '動六福',
#    'inferConfidence': 0.928,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 211.0, 'y': 66.0},
#      {'x': 223.0, 'y': 66.0},
#      {'x': 223.0, 'y': 113.0},
#      {'x': 211.0, 'y': 113.0}]},
#    'inferText': '市喝託',
#    'inferConfidence': 0.7863,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 171.0, 'y': 128.0},
#      {'x': 223.0, 'y': 129.0},
#      {'x': 222.0, 'y': 144.0},
#      {'x': 171.0, 'y': 143.0}]},
#    'inferText': '森小見',
#    'inferConfidence': 0.9962,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 188.0, 'y': 291.0},
#      {'x': 204.0, 'y': 291.0},
#      {'x': 204.0, 'y': 306.0},
#      {'x': 188.0, 'y': 306.0}]},
#    'inferText': '坂',
#    'inferConfidence': 0.9991,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 188.0, 'y': 319.0},
#      {'x': 204.0, 'y': 319.0},
#      {'x': 204.0, 'y': 333.0},
#      {'x': 188.0, 'y': 333.0}]},
#    'inferText': '上',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 149.0, 'y': 64.0},
#      {'x': 167.0, 'y': 65.0},
#      {'x': 166.0, 'y': 98.0},
#      {'x': 148.0, 'y': 98.0}]},
#    'inferText': '〇人',
#    'inferConfidence': 0.947,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 146.0, 'y': 111.0},
#      {'x': 168.0, 'y': 111.0},
#      {'x': 168.0, 'y': 131.0},
#      {'x': 146.0, 'y': 131.0}]},
#    'inferText': '事',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 146.0, 'y': 144.0},
#      {'x': 166.0, 'y': 144.0},
#      {'x': 166.0, 'y': 163.0},
#      {'x': 146.0, 'y': 163.0}]},
#    'inferText': '課',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 124.0, 'y': 64.0},
#      {'x': 138.0, 'y': 65.0},
#      {'x': 136.0, 'y': 99.0},
#      {'x': 123.0, 'y': 98.0}]},
#    'inferText': '主事ニ',
#    'inferConfidence': 0.8341,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 123.0, 'y': 230.0},
#      {'x': 135.0, 'y': 230.0},
#      {'x': 135.0, 'y': 304.0},
#      {'x': 123.0, 'y': 304.0}]},
#    'inferText': '課長',
#    'inferConfidence': 0.9984,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 120.0, 'y': 318.0},
#      {'x': 136.0, 'y': 318.0},
#      {'x': 136.0, 'y': 333.0},
#      {'x': 120.0, 'y': 333.0}]},
#    'inferText': '野',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 121.0, 'y': 346.0},
#      {'x': 136.0, 'y': 346.0},
#      {'x': 136.0, 'y': 361.0},
#      {'x': 121.0, 'y': 361.0}]},
#    'inferText': '定',
#    'inferConfidence': 0.9997,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 121.0, 'y': 374.0},
#      {'x': 134.0, 'y': 374.0},
#      {'x': 134.0, 'y': 389.0},
#      {'x': 121.0, 'y': 389.0}]},
#    'inferText': '男',
#    'inferConfidence': 0.9996,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 111.0, 'y': 298.0},
#      {'x': 119.0, 'y': 298.0},
#      {'x': 119.0, 'y': 380.0},
#      {'x': 111.0, 'y': 380.0}]},
#    'inferText': '、容、ゲ、ゲ短く、八五〇',
#    'inferConfidence': 0.6804,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 104.0, 'y': 298.0},
#      {'x': 110.0, 'y': 298.0},
#      {'x': 109.0, 'y': 362.0},
#      {'x': 103.0, 'y': 362.0}]},
#    'inferText': '(森谷温 西丸二五',
#    'inferConfidence': 0.3388,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 87.0, 'y': 176.0},
#      {'x': 97.0, 'y': 176.0},
#      {'x': 97.0, 'y': 199.0},
#      {'x': 87.0, 'y': 199.0}]},
#    'inferText': '自働',
#    'inferConfidence': 0.9908,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 87.0, 'y': 217.0},
#      {'x': 97.0, 'y': 218.0},
#      {'x': 97.0, 'y': 252.0},
#      {'x': 86.0, 'y': 251.0}]},
#    'inferText': '三〇六',
#    'inferConfidence': 0.9804,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 78.0, 'y': 95.0},
#      {'x': 94.0, 'y': 95.0},
#      {'x': 94.0, 'y': 159.0},
#      {'x': 78.0, 'y': 159.0}]},
#    'inferText': '無務掛',
#    'inferConfidence': 0.8905,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 75.0, 'y': 175.0},
#      {'x': 86.0, 'y': 175.0},
#      {'x': 85.0, 'y': 239.0},
#      {'x': 74.0, 'y': 239.0}]},
#    'inferText': '窮專二○八·',
#    'inferConfidence': 0.8675,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 75.0, 'y': 241.0},
#      {'x': 84.0, 'y': 241.0},
#      {'x': 84.0, 'y': 249.0},
#      {'x': 75.0, 'y': 249.0}]},
#    'inferText': '八',
#    'inferConfidence': 0.5847,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 55.0, 'y': 65.0},
#      {'x': 68.0, 'y': 65.0},
#      {'x': 68.0, 'y': 108.0},
#      {'x': 55.0, 'y': 108.0}]},
#    'inferText': '主事+-',
#    'inferConfidence': 0.7131,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 55.0, 'y': 205.0},
#      {'x': 68.0, 'y': 205.0},
#      {'x': 68.0, 'y': 234.0},
#      {'x': 55.0, 'y': 234.0}]},
#    'inferText': '掛長、',
#    'inferConfidence': 0.9933,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 55.0, 'y': 241.0},
#      {'x': 69.0, 'y': 241.0},
#      {'x': 67.0, 'y': 305.0},
#      {'x': 52.0, 'y': 304.0}]},
#    'inferText': '情報主任廣',
#    'inferConfidence': 0.9994,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 51.0, 'y': 317.0},
#      {'x': 68.0, 'y': 317.0},
#      {'x': 68.0, 'y': 333.0},
#      {'x': 51.0, 'y': 333.0}]},
#    'inferText': '瀨',
#    'inferConfidence': 0.9975,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 51.0, 'y': 346.0},
#      {'x': 67.0, 'y': 346.0},
#      {'x': 67.0, 'y': 362.0},
#      {'x': 51.0, 'y': 362.0}]},
#    'inferText': '為',
#    'inferConfidence': 0.9989,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 50.0, 'y': 373.0},
#      {'x': 66.0, 'y': 373.0},
#      {'x': 66.0, 'y': 389.0},
#      {'x': 50.0, 'y': 389.0}]},
#    'inferText': '吉',
#    'inferConfidence': 1.0,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 43.0, 'y': 298.0},
#      {'x': 50.0, 'y': 298.0},
#      {'x': 50.0, 'y': 305.0},
#      {'x': 43.0, 'y': 305.0}]},
#    'inferText': '特',
#    'inferConfidence': 0.1484,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 42.0, 'y': 304.0},
#      {'x': 51.0, 'y': 304.0},
#      {'x': 51.0, 'y': 314.0},
#      {'x': 42.0, 'y': 314.0}]},
#    'inferText': '美',
#    'inferConfidence': 0.3502,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 42.0, 'y': 322.0},
#      {'x': 50.0, 'y': 322.0},
#      {'x': 51.0, 'y': 371.0},
#      {'x': 43.0, 'y': 371.0}]},
#    'inferText': '下石齏井二ノ',
#    'inferConfidence': 0.9867,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 41.0, 'y': 374.0},
#      {'x': 51.0, 'y': 374.0},
#      {'x': 51.0, 'y': 388.0},
#      {'x': 41.0, 'y': 388.0}]},
#    'inferText': '天',
#    'inferConfidence': 0.4523,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 35.0, 'y': 299.0},
#      {'x': 41.0, 'y': 299.0},
#      {'x': 41.0, 'y': 305.0},
#      {'x': 35.0, 'y': 305.0}]},
#    'inferText': 'き',
#    'inferConfidence': 0.2658,
#    'type': 'NORMAL',
#    'lineBreak': False},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 34.0, 'y': 306.0},
#      {'x': 41.0, 'y': 306.0},
#      {'x': 41.0, 'y': 314.0},
#      {'x': 34.0, 'y': 314.0}]},
#    'inferText': 'C',
#    'inferConfidence': 0.3367,
#    'type': 'NORMAL',
#    'lineBreak': True},
#   {'valueType': 'ALL',
#    'boundingPoly': {'vertices': [{'x': 0.0, 'y': 64.0},
#      {'x': 5.0, 'y': 64.0},
#      {'x': 5.0, 'y': 87.0},
#      {'x': 0.0, 'y': 87.0}]},
#    'inferText': 'I',
#    'inferConfidence': 0.0847,
#    'type': 'NORMAL',
#    'lineBreak': True}]}
