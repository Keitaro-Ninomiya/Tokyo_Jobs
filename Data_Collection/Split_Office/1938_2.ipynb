# %%
import json
import os
import pandas as pd
import numpy as np
import cv2

Year='1938'
Showa='13'

# %%
file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())

df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

# %%
for n in range(0,len(df)):
    
    Row  = df.iloc[n]
    Dept=Row['Dept']
    Office=Row['Office']

    Info=dta[str(Year)][Dept][Office]
    PageList=Info['Page_Range']
    print(Info)
    StrPage=PageList[0]
    StrCord=Info['Office_X1']
    EndPage=PageList[-1]
    EndCord=Info['Office_X2']
    
    if (StrPage=="N"):
        continue
    if (EndPage=="A"):
        continue
    if (StrCord=="NA"):
        continue
    if (EndCord=="NA"):
        continue

    path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\'+str(Year)+'\\'
    save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
    os.chdir(save_path)

    Count=1
    if StrPage!=EndPage:
        for Page in PageList:
            if Page==StrPage:
                print("Starting at"+str(Page)+"|Count is"+str(Count))
                img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,0:StrCord]
                #cv2.imshow("Start",img)
                #cv2.waitKey(0)
                cv2.imwrite('Image'+str(Count)+'.png', img)
                Count=Count+1
            if Page==EndPage:
                print("Ending at"+str(Page)+"|Count is"+str(Count))
                img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,EndCord:WW]
                #cv2.imshow("End",img)
                #cv2.waitKey(0)
                cv2.imwrite('Image'+str(Count)+'.png', img)
            if (Page!=StrPage) and (Page<EndPage):
                print("Continuing at"+str(Page)+"|Count is"+str(Count))
                img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,0:WW]
                #cv2.imshow("Interim",img)
                #cv2.waitKey(0)
                cv2.imwrite('Image'+str(Count)+'.png', img)
                Count=Count+1
    if StrPage==EndPage:
        img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
        HH, WW = img.shape[:2]
        img=img[0:HH,EndCord:StrCord]
        cv2.imwrite('Image'+str(Count)+'.png', img)
# Out:
# {'Starting_Page': 2, 'Office_X1': 480, 'Ending_Page': 2, 'Office_X2': 178, 'Page_Range': [2]}
# {'Starting_Page': 2, 'Office_X1': 168, 'Ending_Page': 4, 'Office_X2': 377, 'Page_Range': [2, 3, 4]}
# Starting at2|Count is1
# Continuing at3|Count is2
# Ending at4|Count is3
# {'Starting_Page': 4, 'Office_X1': 367, 'Ending_Page': 6, 'Office_X2': 145, 'Page_Range': [4, 5, 6]}
# Starting at4|Count is1
# Continuing at5|Count is2
# Ending at6|Count is3
# {'Starting_Page': 6, 'Office_X1': 135, 'Ending_Page': 7, 'Office_X2': 255, 'Page_Range': [6, 7]}
# Starting at6|Count is1
# Ending at7|Count is2
# {'Starting_Page': 7, 'Office_X1': 245, 'Ending_Page': 8, 'Office_X2': 217, 'Page_Range': [7, 8]}
# Starting at7|Count is1
# Ending at8|Count is2
# {'Starting_Page': 8, 'Office_X1': 207, 'Ending_Page': 9, 'Office_X2': 165, 'Page_Range': [8, 9]}
# Starting at8|Count is1
# Ending at9|Count is2
# {'Starting_Page': 9, 'Office_X1': 155, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 20, 'Office_X1': 'NA', 'Ending_Page': 24, 'Office_X2': 311, 'Page_Range': [20, 21, 22, 23, 24]}
# {'Starting_Page': 24, 'Office_X1': 301, 'Ending_Page': 26, 'Office_X2': 190, 'Page_Range': [24, 25, 26]}
# Starting at24|Count is1
# Continuing at25|Count is2
# Ending at26|Count is3
# {'Starting_Page': 26, 'Office_X1': 180, 'Ending_Page': 27, 'Office_X2': 103, 'Page_Range': [26, 27]}
# Starting at26|Count is1
# Ending at27|Count is2
# {'Starting_Page': 27, 'Office_X1': 93, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 34, 'Office_X1': 'NA', 'Ending_Page': 39, 'Office_X2': 464, 'Page_Range': [34, 35, 36, 37, 38, 39]}
# {'Starting_Page': 39, 'Office_X1': 454, 'Ending_Page': 43, 'Office_X2': 237, 'Page_Range': [39, 40, 41, 42, 43]}
# Starting at39|Count is1
# Continuing at40|Count is2
# Continuing at41|Count is3
# Continuing at42|Count is4
# Ending at43|Count is5
# {'Starting_Page': 43, 'Office_X1': 227, 'Ending_Page': 48, 'Office_X2': 71, 'Page_Range': [43, 44, 45, 46, 47, 48]}
# Starting at43|Count is1
# Continuing at44|Count is2
# Continuing at45|Count is3
# Continuing at46|Count is4
# Continuing at47|Count is5
# Ending at48|Count is6
# {'Starting_Page': 48, 'Office_X1': 61, 'Ending_Page': 49, 'Office_X2': 112, 'Page_Range': [48, 49]}
# Starting at48|Count is1
# Ending at49|Count is2
# {'Starting_Page': 49, 'Office_X1': 102, 'Ending_Page': 52, 'Office_X2': 171, 'Page_Range': [49, 50, 51, 52]}
# Starting at49|Count is1
# Continuing at50|Count is2
# Continuing at51|Count is3
# Ending at52|Count is4
# {'Starting_Page': 52, 'Office_X1': 161, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 53, 'Office_X1': 'NA', 'Ending_Page': 54, 'Office_X2': 257, 'Page_Range': [53, 54]}
# {'Starting_Page': 54, 'Office_X1': 247, 'Ending_Page': 56, 'Office_X2': 223, 'Page_Range': [54, 55, 56]}
# Starting at54|Count is1
# Continuing at55|Count is2
# Ending at56|Count is3
# {'Starting_Page': 56, 'Office_X1': 213, 'Ending_Page': 57, 'Office_X2': 179, 'Page_Range': [56, 57]}
# Starting at56|Count is1
# Ending at57|Count is2
# {'Starting_Page': 57, 'Office_X1': 169, 'Ending_Page': 58, 'Office_X2': 40, 'Page_Range': [57, 58]}
# Starting at57|Count is1
# Ending at58|Count is2
# {'Starting_Page': 58, 'Office_X1': 30, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 60, 'Office_X1': 'NA', 'Ending_Page': 66, 'Office_X2': 238, 'Page_Range': [60, 61, 62, 63, 64, 65, 66]}
# {'Starting_Page': 66, 'Office_X1': 228, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 69, 'Office_X1': 'NA', 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 75, 'Office_X1': 'NA', 'Ending_Page': 76, 'Office_X2': 175, 'Page_Range': [75, 76]}
# {'Starting_Page': 76, 'Office_X1': 165, 'Ending_Page': 90, 'Office_X2': 37, 'Page_Range': [76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90]}
# Starting at76|Count is1
# Continuing at77|Count is2
# Continuing at78|Count is3
# Continuing at79|Count is4
# Continuing at80|Count is5
# Continuing at81|Count is6
# Continuing at82|Count is7
# Continuing at83|Count is8
# Continuing at84|Count is9
# Continuing at85|Count is10
# Continuing at86|Count is11
# Continuing at87|Count is12
# Continuing at88|Count is13
# Continuing at89|Count is14
# Ending at90|Count is15
# {'Starting_Page': 90, 'Office_X1': 27, 'Ending_Page': 94, 'Office_X2': 259, 'Page_Range': [90, 91, 92, 93, 94]}
# Starting at90|Count is1
# Continuing at91|Count is2
# Continuing at92|Count is3
# Continuing at93|Count is4
# Ending at94|Count is5
# {'Starting_Page': 94, 'Office_X1': 249, 'Ending_Page': 101, 'Office_X2': 344, 'Page_Range': [94, 95, 96, 97, 98, 99, 100, 101]}
# Starting at94|Count is1
# Continuing at95|Count is2
# Continuing at96|Count is3
# Continuing at97|Count is4
# Continuing at98|Count is5
# Continuing at99|Count is6
# Continuing at100|Count is7
# Ending at101|Count is8
# {'Starting_Page': 101, 'Office_X1': 334, 'Ending_Page': 102, 'Office_X2': 82, 'Page_Range': [101, 102]}
# Starting at101|Count is1
# Ending at102|Count is2
# {'Starting_Page': 102, 'Office_X1': 72, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 116, 'Office_X1': 'NA', 'Ending_Page': 122, 'Office_X2': 161, 'Page_Range': [116, 117, 118, 119, 120, 121, 122]}
# {'Starting_Page': 122, 'Office_X1': 151, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 126, 'Office_X1': 'NA', 'Ending_Page': 127, 'Office_X2': 394, 'Page_Range': [126, 127]}
# {'Starting_Page': 127, 'Office_X1': 384, 'Ending_Page': 151, 'Office_X2': 405, 'Page_Range': [127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151]}
# Starting at127|Count is1
# Continuing at128|Count is2
# Continuing at129|Count is3
# Continuing at130|Count is4
# Continuing at131|Count is5
# Continuing at132|Count is6
# Continuing at133|Count is7
# Continuing at134|Count is8
# Continuing at135|Count is9
# Continuing at136|Count is10
# Continuing at137|Count is11
# Continuing at138|Count is12
# Continuing at139|Count is13
# Continuing at140|Count is14
# Continuing at141|Count is15
# Continuing at142|Count is16
# Continuing at143|Count is17
# Continuing at144|Count is18
# Continuing at145|Count is19
# Continuing at146|Count is20
# Continuing at147|Count is21
# Continuing at148|Count is22
# Continuing at149|Count is23
# Continuing at150|Count is24
# Ending at151|Count is25
# {'Starting_Page': 151, 'Office_X1': 395, 'Ending_Page': 156, 'Office_X2': 151, 'Page_Range': [151, 152, 153, 154, 155, 156]}
# Starting at151|Count is1
# Continuing at152|Count is2
# Continuing at153|Count is3
# Continuing at154|Count is4
# Continuing at155|Count is5
# Ending at156|Count is6
# {'Starting_Page': 156, 'Office_X1': 141, 'Ending_Page': 162, 'Office_X2': 172, 'Page_Range': [156, 157, 158, 159, 160, 161, 162]}
# Starting at156|Count is1
# Continuing at157|Count is2
# Continuing at158|Count is3
# Continuing at159|Count is4
# Continuing at160|Count is5
# Continuing at161|Count is6
# Ending at162|Count is7
# {'Starting_Page': 162, 'Office_X1': 162, 'Ending_Page': 171, 'Office_X2': 326, 'Page_Range': [162, 163, 164, 165, 166, 167, 168, 169, 170, 171]}
# Starting at162|Count is1
# Continuing at163|Count is2
# Continuing at164|Count is3
# Continuing at165|Count is4
# Continuing at166|Count is5
# Continuing at167|Count is6
# Continuing at168|Count is7
# Continuing at169|Count is8
# Continuing at170|Count is9
# Ending at171|Count is10
# {'Starting_Page': 171, 'Office_X1': 316, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 173, 'Office_X1': 'NA', 'Ending_Page': 177, 'Office_X2': 282, 'Page_Range': [173, 174, 175, 176, 177]}
# {'Starting_Page': 177, 'Office_X1': 272, 'Ending_Page': 181, 'Office_X2': 347, 'Page_Range': [177, 178, 179, 180, 181]}
# Starting at177|Count is1
# Continuing at178|Count is2
# Continuing at179|Count is3
# Continuing at180|Count is4
# Ending at181|Count is5
# {'Starting_Page': 181, 'Office_X1': 337, 'Ending_Page': 199, 'Office_X2': 120, 'Page_Range': [181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199]}
# Starting at181|Count is1
# Continuing at182|Count is2
# Continuing at183|Count is3
# Continuing at184|Count is4
# Continuing at185|Count is5
# Continuing at186|Count is6
# Continuing at187|Count is7
# Continuing at188|Count is8
# Continuing at189|Count is9
# Continuing at190|Count is10
# Continuing at191|Count is11
# Continuing at192|Count is12
# Continuing at193|Count is13
# Continuing at194|Count is14
# Continuing at195|Count is15
# Continuing at196|Count is16
# Continuing at197|Count is17
# Continuing at198|Count is18
# Ending at199|Count is19
# {'Starting_Page': 199, 'Office_X1': 110, 'Ending_Page': 201, 'Office_X2': 169, 'Page_Range': [199, 200, 201]}
# Starting at199|Count is1
# Continuing at200|Count is2
# Ending at201|Count is3
# {'Starting_Page': 201, 'Office_X1': 159, 'Ending_Page': 203, 'Office_X2': 229, 'Page_Range': [201, 202, 203]}
# Starting at201|Count is1
# Continuing at202|Count is2
# Ending at203|Count is3
# {'Starting_Page': 203, 'Office_X1': 219, 'Ending_Page': 205, 'Office_X2': 361, 'Page_Range': [203, 204, 205]}
# Starting at203|Count is1
# Continuing at204|Count is2
# Ending at205|Count is3
# {'Starting_Page': 205, 'Office_X1': 351, 'Ending_Page': 208, 'Office_X2': 465, 'Page_Range': [205, 206, 207, 208]}
# Starting at205|Count is1
# Continuing at206|Count is2
# Continuing at207|Count is3
# Ending at208|Count is4
# {'Starting_Page': 208, 'Office_X1': 455, 'Ending_Page': 209, 'Office_X2': 273, 'Page_Range': [208, 209]}
# Starting at208|Count is1
# Ending at209|Count is2
# {'Starting_Page': 209, 'Office_X1': 263, 'Ending_Page': 212, 'Office_X2': 361, 'Page_Range': [209, 210, 211, 212]}
# Starting at209|Count is1
# Continuing at210|Count is2
# Continuing at211|Count is3
# Ending at212|Count is4
# {'Starting_Page': 212, 'Office_X1': 351, 'Ending_Page': 213, 'Office_X2': 131, 'Page_Range': [212, 213]}
# Starting at212|Count is1
# Ending at213|Count is2
# {'Starting_Page': 213, 'Office_X1': 121, 'Ending_Page': 216, 'Office_X2': 338, 'Page_Range': [213, 214, 215, 216]}
# Starting at213|Count is1
# Continuing at214|Count is2
# Continuing at215|Count is3
# Ending at216|Count is4
# {'Starting_Page': 216, 'Office_X1': 328, 'Ending_Page': 219, 'Office_X2': 455, 'Page_Range': [216, 217, 218, 219]}
# Starting at216|Count is1
# Continuing at217|Count is2
# Continuing at218|Count is3
# Ending at219|Count is4
# {'Starting_Page': 219, 'Office_X1': 445, 'Ending_Page': 241, 'Office_X2': 220, 'Page_Range': [219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241]}
# Starting at219|Count is1
# Continuing at220|Count is2
# Continuing at221|Count is3
# Continuing at222|Count is4
# Continuing at223|Count is5
# Continuing at224|Count is6
# Continuing at225|Count is7
# Continuing at226|Count is8
# Continuing at227|Count is9
# Continuing at228|Count is10
# Continuing at229|Count is11
# Continuing at230|Count is12
# Continuing at231|Count is13
# Continuing at232|Count is14
# Continuing at233|Count is15
# Continuing at234|Count is16
# Continuing at235|Count is17
# Continuing at236|Count is18
# Continuing at237|Count is19
# Continuing at238|Count is20
# Continuing at239|Count is21
# Continuing at240|Count is22
# Ending at241|Count is23
# {'Starting_Page': 241, 'Office_X1': 210, 'Ending_Page': 244, 'Office_X2': 156, 'Page_Range': [241, 242, 243, 244]}
# Starting at241|Count is1
# Continuing at242|Count is2
# Continuing at243|Count is3
# Ending at244|Count is4
# {'Starting_Page': 244, 'Office_X1': 146, 'Ending_Page': 246, 'Office_X2': 283, 'Page_Range': [244, 245, 246]}
# Starting at244|Count is1
# Continuing at245|Count is2
# Ending at246|Count is3
# {'Starting_Page': 246, 'Office_X1': 273, 'Ending_Page': 260, 'Office_X2': 169, 'Page_Range': [246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260]}
# Starting at246|Count is1
# Continuing at247|Count is2
# Continuing at248|Count is3
# Continuing at249|Count is4
# Continuing at250|Count is5
# Continuing at251|Count is6
# Continuing at252|Count is7
# Continuing at253|Count is8
# Continuing at254|Count is9
# Continuing at255|Count is10
# Continuing at256|Count is11
# Continuing at257|Count is12
# Continuing at258|Count is13
# Continuing at259|Count is14
# Ending at260|Count is15
# {'Starting_Page': 260, 'Office_X1': 159, 'Ending_Page': 262, 'Office_X2': 394, 'Page_Range': [260, 261, 262]}
# Starting at260|Count is1
# Continuing at261|Count is2
# Ending at262|Count is3
# {'Starting_Page': 262, 'Office_X1': 384, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 264, 'Office_X1': 'NA', 'Ending_Page': 265, 'Office_X2': 282, 'Page_Range': [264, 265]}
# {'Starting_Page': 265, 'Office_X1': 272, 'Ending_Page': 267, 'Office_X2': 431, 'Page_Range': [265, 266, 267]}
# Starting at265|Count is1
# Continuing at266|Count is2
# Ending at267|Count is3
# {'Starting_Page': 267, 'Office_X1': 421, 'Ending_Page': 268, 'Office_X2': 387, 'Page_Range': [267, 268]}
# Starting at267|Count is1
# Ending at268|Count is2
# {'Starting_Page': 268, 'Office_X1': 377, 'Ending_Page': 273, 'Office_X2': 437, 'Page_Range': [268, 269, 270, 271, 272, 273]}
# Starting at268|Count is1
# Continuing at269|Count is2
# Continuing at270|Count is3
# Continuing at271|Count is4
# Continuing at272|Count is5
# Ending at273|Count is6
# {'Starting_Page': 273, 'Office_X1': 427, 'Ending_Page': 283, 'Office_X2': 148, 'Page_Range': [273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283]}
# Starting at273|Count is1
# Continuing at274|Count is2
# Continuing at275|Count is3
# Continuing at276|Count is4
# Continuing at277|Count is5
# Continuing at278|Count is6
# Continuing at279|Count is7
# Continuing at280|Count is8
# Continuing at281|Count is9
# Continuing at282|Count is10
# Ending at283|Count is11
# {'Starting_Page': 283, 'Office_X1': 138, 'Ending_Page': 284, 'Office_X2': 66, 'Page_Range': [283, 284]}
# Starting at283|Count is1
# Ending at284|Count is2
# {'Starting_Page': 284, 'Office_X1': 56, 'Ending_Page': 286, 'Office_X2': 52, 'Page_Range': [284, 285, 286]}
# Starting at284|Count is1
# Continuing at285|Count is2
# Ending at286|Count is3
# {'Starting_Page': 286, 'Office_X1': 42, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 287, 'Office_X1': 'NA', 'Ending_Page': 289, 'Office_X2': 295, 'Page_Range': [287, 288, 289]}
# {'Starting_Page': 289, 'Office_X1': 285, 'Ending_Page': 293, 'Office_X2': 453, 'Page_Range': [289, 290, 291, 292, 293]}
# Starting at289|Count is1
# Continuing at290|Count is2
# Continuing at291|Count is3
# Continuing at292|Count is4
# Ending at293|Count is5
# {'Starting_Page': 293, 'Office_X1': 443, 'Ending_Page': 294, 'Office_X2': 227, 'Page_Range': [293, 294]}
# Starting at293|Count is1
# Ending at294|Count is2
# {'Starting_Page': 294, 'Office_X1': 217, 'Ending_Page': 295, 'Office_X2': 207, 'Page_Range': [294, 295]}
# Starting at294|Count is1
# Ending at295|Count is2
# {'Starting_Page': 295, 'Office_X1': 197, 'Ending_Page': 296, 'Office_X2': 120, 'Page_Range': [295, 296]}
# Starting at295|Count is1
# Ending at296|Count is2
# {'Starting_Page': 296, 'Office_X1': 110, 'Ending_Page': 299, 'Office_X2': 230, 'Page_Range': [296, 297, 298, 299]}
# Starting at296|Count is1
# Continuing at297|Count is2
# Continuing at298|Count is3
# Ending at299|Count is4
# {'Starting_Page': 299, 'Office_X1': 220, 'Ending_Page': 300, 'Office_X2': 384, 'Page_Range': [299, 300]}
# Starting at299|Count is1
# Ending at300|Count is2
# {'Starting_Page': 300, 'Office_X1': 374, 'Ending_Page': 300, 'Office_X2': 50, 'Page_Range': [300]}
# {'Starting_Page': 300, 'Office_X1': 40, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 301, 'Office_X1': 'NA', 'Ending_Page': 302, 'Office_X2': 256, 'Page_Range': [301, 302]}
# {'Starting_Page': 302, 'Office_X1': 246, 'Ending_Page': 303, 'Office_X2': 390, 'Page_Range': [302, 303]}
# Starting at302|Count is1
# Ending at303|Count is2
# {'Starting_Page': 303, 'Office_X1': 380, 'Ending_Page': 303, 'Office_X2': 52, 'Page_Range': [303]}
# {'Starting_Page': 303, 'Office_X1': 42, 'Ending_Page': 305, 'Office_X2': 310, 'Page_Range': [303, 304, 305]}
# Starting at303|Count is1
# Continuing at304|Count is2
# Ending at305|Count is3
# {'Starting_Page': 305, 'Office_X1': 300, 'Ending_Page': 306, 'Office_X2': 477, 'Page_Range': [305, 306]}
# Starting at305|Count is1
# Ending at306|Count is2
# {'Starting_Page': 306, 'Office_X1': 467, 'Ending_Page': 309, 'Office_X2': 207, 'Page_Range': [306, 307, 308, 309]}
# Starting at306|Count is1
# Continuing at307|Count is2
# Continuing at308|Count is3
# Ending at309|Count is4
# {'Starting_Page': 309, 'Office_X1': 197, 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 311, 'Office_X1': 'NA', 'Ending_Page': 'NA', 'Office_X2': 'NA', 'Page_Range': 'NA'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Temp\ipykernel_13616\2193851201.py in <module>
#       6
#       7     Info=dta[str(Year)][Dept][Office]
# ----> 8     PageList=Info['Page_Range']
#       9     print(Info)
#      10     StrPage=PageList[0]
#
# KeyError: 'Page_Range'

# %%
n=3
Row  = df.iloc[n]
Dept=Row['Dept']
Office=Row['Office']
print(Row)

Info=dta[str(Year)][Dept][Office]
PageList=Info['Page_Range']
print(Info)
StrPage=PageList[0]
StrCord=Info['Office_X1']
EndPage=PageList[-1]
EndCord=Info['Office_X2']

path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\'+str(Year)+'\\'
save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
os.chdir(save_path)

Count=1
if StrPage!=EndPage:
    for Page in PageList:
        if Page==StrPage:
            print("Starting at"+str(Page)+"|Count is"+str(Count))
            img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,0:StrCord]
            cv2.imshow("Start",img)
            cv2.waitKey(0)
            cv2.imwrite('Image'+str(Count)+'.png', img)
            Count=Count+1
        if Page==EndPage:
            print("Ending at"+str(Page)+"|Count is"+str(Count))
            img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,EndCord:WW]
            cv2.imshow("End",img)
            cv2.waitKey(0)
            cv2.imwrite('Image'+str(Count)+'.png', img)
        if (Page!=StrPage) and (Page<EndPage):
            print("Continuing at"+str(Page)+"|Count is"+str(Count))
            img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,0:WW]
            cv2.imshow("Interim",img)
            cv2.waitKey(0)
            cv2.imwrite('Image'+str(Count)+'.png', img)
            Count=Count+1
if StrPage==EndPage:
    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
    HH, WW = img.shape[:2]
    img=img[0:HH,EndCord:StrCord]
    cv2.imwrite('Image'+str(Count)+'.png', img)
# Out:
# Office    庶務課
# Dept      監査局
# Year        9
# Page        5
# Name: 3, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Temp\ipykernel_32088\2363960203.py in <module>
#       6
#       7 Info=dta[str(Year)][Dept][Office]
# ----> 8 PageList=Info['Page_Range']
#       9 print(Info)
#      10 StrPage=PageList[0]
#
# KeyError: 'Page_Range'

# %%
Info=dta[str(Year)][Dept][Office]
Info
# Out:
# {'Starting_Page': 5, 'Office_X1': 429}
