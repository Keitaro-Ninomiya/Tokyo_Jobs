# %%
import json
import os
import pandas as pd
import numpy as np
import cv2

Year='1934'
Showa='9'

# %%
file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())
df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

# %%
n=0
Row  = df.iloc[n]
Dept=Row['Dept']
Office=Row['Office']
Info=dta[str(Year)][Dept][Office]
PageList=Info['Page_Range']
PosiList=list(Info['Position'].keys())
print(PosiList)
# Out:
# ['Leader', 'Manager', 'Admin']

# %%
save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
os.chdir(save_path)
Count=1

for Position in PosiList:
    print(Position)
    StrPage=int(dta[Year][Dept][Office]['Position'][Position]['Page'])
    StrCord=int(dta[Year][Dept][Office]['Position'][Position]['XLocation'])
    EndPage=int(dta[Year][Dept][Office]['Position'][Position]['EndPage'])
    EndCord=int(dta[Year][Dept][Office]['Position'][Position]['EndLocation'])
    print()
    print("Start Page is "+str(StrPage))
    print("End Page is "+str(EndPage))
    
    if StrPage==EndPage:
        if StrCord<EndCord:
            print('Error! Coordinate size is reversed for '+Office+' of '+Dept)
            continue
        print("One Page")
        stream = open(save_path+"//Image"+str(Count)+".png", "rb")
        bytes = bytearray(stream.read())
        numpyarray = np.asarray(bytes, dtype=np.uint8)
        img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)

        HH, WW = img.shape[:2]
        print(EndCord,StrCord)
        img=img[0:HH,EndCord:StrCord]
        cv2.imshow("Start",img)
        cv2.waitKey(0)
        cv2.imwrite(Position+'\\Image'+str(1)+'.png', img)
        
    else:
        for Page in range(StrPage,EndPage):
            print("Multiple Page")
            if Page==StrPage:
                SubCount=1
                stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                bytes = bytearray(stream.read())
                numpyarray = np.asarray(bytes, dtype=np.uint8)
                img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)
                HH, WW = img.shape[:2]

                img=img[0:HH,0:StrCord]
                cv2.imshow("Start",img)
                cv2.waitKey(0)
                cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
                Count=Count+1
                SubCount=SubCount+1
                
            if (Page>StrPage) and (Page<EndPage):
                stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                bytes = bytearray(stream.read())
                numpyarray = np.asarray(bytes, dtype=np.uint8)
                img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)
                
                HH, WW = img.shape[:2]
                img=img[0:HH,0:WW]
                cv2.imshow("Middle",img)
                cv2.waitKey(0)
                cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
                SubCount=SubCount+1
                
            if (Page==EndPage):
                stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                bytes = bytearray(stream.read())
                numpyarray = np.asarray(bytes, dtype=np.uint8)
                img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)

                HH, WW = img.shape[:2]
                img=img[0:HH,0:WW]
                cv2.imshow("End",img)
                cv2.waitKey(0)
                cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
# Out:
# Leader
#
# Start Page is 2
# End Page is 2
# One Page
# 100 136
# Manager
#
# Start Page is 2
# End Page is 2
# One Page
# 51 100
# Admin
#
# Start Page is 2
# End Page is 2
# Error! Coordinate size is reversed for 秘書課 of Admin

# %%
for n in range(1,len(df)+1): 
    Row  = df.iloc[n]
    Dept=Row['Dept']
    Office=Row['Office']
    Info=dta[str(Year)][Dept][Office]
    PageList=Info['Page_Range']
    if PageList=='NA':
        continue
    try:
        PosiList=list(Info['Position'].keys())
    except:
        continue
    
    save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
    try:
        os.chdir(save_path)
    except:
        continue

    Count=1
    for Position in PosiList:
        print(Position)
        StrPage=int(dta[Year][Dept][Office]['Position'][Position]['Page'])
        StrCord=int(dta[Year][Dept][Office]['Position'][Position]['XLocation'])
        EndPage=int(dta[Year][Dept][Office]['Position'][Position]['EndPage'])
        EndCord=int(dta[Year][Dept][Office]['Position'][Position]['EndLocation'])
        if 'NA' in list((StrPage,StrCord,EndPage,EndCord)):
            continue
    
        print()
        print("Start Page is "+str(StrPage))
        print("End Page is "+str(EndPage))

        if StrPage==EndPage:
            if StrCord<EndCord:
                print('Error! Coordinate size is reversed for '+Office+' of '+Dept)
                continue
            print("One Page")
            stream = open(save_path+"//Image"+str(Count)+".png", "rb")
            bytes = bytearray(stream.read())
            numpyarray = np.asarray(bytes, dtype=np.uint8)
            img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)

            HH, WW = img.shape[:2]
            print(EndCord,StrCord)
            img=img[0:HH,EndCord:StrCord]
            cv2.imwrite(Position+'\\Image'+str(1)+'.png', img)

        else:
            for Page in range(StrPage,EndPage):
                print("Multiple Page")
                if Page==StrPage:
                    SubCount=1
                    stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                    bytes = bytearray(stream.read())
                    numpyarray = np.asarray(bytes, dtype=np.uint8)
                    img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)
                    HH, WW = img.shape[:2]

                    img=img[0:HH,0:StrCord]
                    cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
                    Count=Count+1
                    SubCount=SubCount+1

                if (Page>StrPage) and (Page<EndPage):
                    stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                    bytes = bytearray(stream.read())
                    numpyarray = np.asarray(bytes, dtype=np.uint8)
                    img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)

                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:WW]
                    cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
                    SubCount=SubCount+1

                if (Page==EndPage):
                    stream = open(save_path+"//Image"+str(Count)+".png", "rb")
                    bytes = bytearray(stream.read())
                    numpyarray = np.asarray(bytes, dtype=np.uint8)
                    img = cv2.imdecode(numpyarray, cv2.IMREAD_UNCHANGED)

                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:WW]
                    cv2.imwrite(Position+'\\Image'+str(SubCount)+'.png', img)
# Out:
# Leader
#
# Start Page is 2
# End Page is 2
# One Page
# 150 179
# Manager
#
# Start Page is 2
# End Page is 3
# Multiple Page
# Admin
#
# Start Page is 3
# End Page is 3
# Error! Coordinate size is reversed for 職員課 of Admin
# Manager
#
# Start Page is 3
# End Page is 3
# One Page
# 242 274
# Leader
#
# Start Page is 3
# End Page is 4
# Multiple Page
# Admin
#
# Start Page is 4
# End Page is 5
# Multiple Page
# Manager
#
# Start Page is 5
# End Page is 5
# One Page
# 213 244
# Leader
#
# Start Page is 5
# End Page is 5
# One Page
# 102 213
# Admin
#
# Start Page is 5
# End Page is 5
# Error! Coordinate size is reversed for 庶務課 of 監査局
# Leader
#
# Start Page is 5
# End Page is 5
# One Page
# 153 177
# Manager
#
# Start Page is 5
# End Page is 6
# Multiple Page
# Admin
#
# Start Page is 6
# End Page is 6
# Error! Coordinate size is reversed for 監察課 of 監査局
# Manager
#
# Start Page is 6
# End Page is 6
# One Page
# 166 196
# Leader
#
# Start Page is 6
# End Page is 7
# Multiple Page
# Admin
#
# Start Page is 7
# End Page is 7
# One Page
# 14 151
# Outsource
#
# Start Page is 7
# End Page is 7
# Error! Coordinate size is reversed for 区政課 of 監査局
# Leader
#
# Start Page is 11
# End Page is 11
# One Page
# 206 231
# Manager
#
# Start Page is 11
# End Page is 12
# Multiple Page
# Admin
#
# Start Page is 12
# End Page is 12
# Error! Coordinate size is reversed for 主計課 of 財務局
# Leader
#
# Start Page is 13
# End Page is 13
# One Page
# 408 433
# Manager
#
# Start Page is 13
# End Page is 13
# One Page
# 119 408
# Admin
#
# Start Page is 13
# End Page is 14
# Multiple Page
# Engineer2
#
# Start Page is 14
# End Page is 17
# Multiple Page
# Multiple Page
# Multiple Page
# Leader
#
# Start Page is 17
# End Page is 17
# One Page
# 79 103
# Manager
#
# Start Page is 17
# End Page is 18
# Multiple Page
# Engineer1
#
# Start Page is 18
# End Page is 18
# One Page
# 326 355
# Admin
#
# Start Page is 18
# End Page is 18
# One Page
# 91 326
# Engineer2
#
# Start Page is 18
# End Page is 19
# Multiple Page
# Manager
#
# Start Page is 19
# End Page is 19
# One Page
# 406 437
# Leader
#
# Start Page is 19
# End Page is 19
# One Page
# 270 406
# Engineer1
#
# Start Page is 19
# End Page is 19
# One Page
# 240 270
# Admin
#
# Start Page is 19
# End Page is 20
# Multiple Page
# Engineer2
#
# Start Page is 20
# End Page is 21
# Multiple Page
# Leader
#
# Start Page is 21
# End Page is 21
# One Page
# 383 402
# Manager
#
# Start Page is 21
# End Page is 21
# One Page
# 267 383
# Admin
#
# Start Page is 21
# End Page is 21
# One Page
# 231 267
# Engineer2
#
# Start Page is 21
# End Page is 21
# One Page
# 119 231
# Leader
#
# Start Page is 21
# End Page is 22
# Multiple Page
# Manager
#
# Start Page is 22
# End Page is 22
# One Page
# 96 130
# Admin
#
# Start Page is 22
# End Page is 22
# Error! Coordinate size is reversed for 庶務課 of 産業局
# Leader
#
# Start Page is 22
# End Page is 22
# One Page
# 247 277
# Manager
#
# Start Page is 22
# End Page is 22
# One Page
# 79 247
# Admin
#
# Start Page is 22
# End Page is 23
# Multiple Page
# Engineer2
#
# Start Page is 23
# End Page is 23
# One Page
# 119 186
# Outsource
#
# Start Page is 23
# End Page is 23
# Error! Coordinate size is reversed for 商工課 of 産業局
# Manager
#
# Start Page is 23
# End Page is 23
# One Page
# 189 219
# Leader
#
# Start Page is 23
# End Page is 23
# One Page
# 125 189
# Engineer1
#
# Start Page is 23
# End Page is 24
# Multiple Page
# Admin
#
# Start Page is 24
# End Page is 24
# One Page
# 434 484
# Engineer2
#
# Start Page is 24
# End Page is 25
# Multiple Page
# Engineer1
#
# Start Page is 25
# End Page is 25
# One Page
# 303 334
# Leader
#
# Start Page is 25
# End Page is 25
# One Page
# 243 303
# Admin
#
# Start Page is 25
# End Page is 25
# One Page
# 223 243
# Engineer2
#
# Start Page is 25
# End Page is 25
# One Page
# 127 223
# Leader
#
# Start Page is 25
# End Page is 25
# One Page
# 91 116
# Manager
#
# Start Page is 25
# End Page is 26
# Multiple Page
# Admin
#
# Start Page is 26
# End Page is 26
# Error! Coordinate size is reversed for 庶務課 of 教育局
# Leader
#
# Start Page is 30
# End Page is 30
# One Page
# 224 263
# Manager
#
# Start Page is 30
# End Page is 30
# One Page
# 151 224
# Engineer1
#
# Start Page is 30
# End Page is 31
# Multiple Page
# Admin
#
# Start Page is 31
# End Page is 31
# One Page
# 179 231
# Outsource
#
# Start Page is 31
# End Page is 32
# Multiple Page
# Engineer2
#
# Start Page is 32
# End Page is 33
# Multiple Page
# Leader
#
# Start Page is 33
# End Page is 33
# One Page
# 277 375
# Manager
#
# Start Page is 33
# End Page is 33
# One Page
# 211 277
# Engineer1
#
# Start Page is 33
# End Page is 34
# Multiple Page
# Engineer2
#
# Start Page is 34
# End Page is 34
# One Page
# 143 212
# Admin
#
# Start Page is 34
# End Page is 34
# One Page
# 55 143
# Outsource
#
# Start Page is 34
# End Page is 36
# Multiple Page
# Multiple Page
# Leader
#
# Start Page is 36
# End Page is 36
# One Page
# 61 91
# Manager
#
# Start Page is 36
# End Page is 37
# Multiple Page
# Admin
#
# Start Page is 37
# End Page is 37
# One Page
# 70 234
# Outsource
#
# Start Page is 37
# End Page is 37
# Error! Coordinate size is reversed for 庶務課 of 社会局
# Leader
#
# Start Page is 43
# End Page is 43
# One Page
# 193 223
# Manager
#
# Start Page is 43
# End Page is 44
# Multiple Page
# Engineer1
#
# Start Page is 44
# End Page is 44
# One Page
# 335 352
# Admin
#
# Start Page is 44
# End Page is 45
# Multiple Page
# Engineer2
#
# Start Page is 45
# End Page is 46
# Multiple Page
# Leader
#
# Start Page is 46
# End Page is 46
# One Page
# 258 279
# Manager
#
# Start Page is 46
# End Page is 47
# Multiple Page
# Engineer1
#
# Start Page is 47
# End Page is 47
# One Page
# 417 448
# Admin
#
# Start Page is 47
# End Page is 47
# One Page
# 199 417
# Engineer2
#
# Start Page is 47
# End Page is 50
# Multiple Page
# Multiple Page
# Multiple Page
# Leader
#
# Start Page is 50
# End Page is 50
# One Page
# 248 272
# Manager
#
# Start Page is 50
# End Page is 50
# One Page
# 79 248
# Admin
#
# Start Page is 50
# End Page is 51
# Multiple Page
# Engineer2
#
# Start Page is 51
# End Page is 51
# Error! Coordinate size is reversed for 庶務課 of 保健局
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Temp\ipykernel_10452\563143122.py in <module>
#       4     Office=Row['Office']
#       5     Info=dta[str(Year)][Dept][Office]
# ----> 6     PageList=Info['Page_Range']
#       7     if PageList=='NA':
#       8         continue
#
# KeyError: 'Page_Range'
