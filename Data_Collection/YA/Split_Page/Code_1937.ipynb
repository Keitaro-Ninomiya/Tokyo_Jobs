# %% [markdown]
# - These codes splits the digital archived copies into page units.
#
# - The codes are executed in the following order.
#     1. Remove redundant spaces around a digital copies.
#
#         <=Removes the areas of the image covered with while color.
#
#     2. Cuts the page at the border of the two pages.
#
#         Borders are detected by searching for a black ertical line.

# %% [markdown]
# Code 1: Define the functions and install packages

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import cv2
import os


def Split(Page):    
    img = cv2.imread(path+"Page"+Page+".jpg")
    hh, ww = img.shape[:2]
    # convert to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # threshold gray image
    thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

    # count number of non-zero pixels in each row. 
    countCol = np.count_nonzero(thresh, axis=0)
    countRow = np.count_nonzero(thresh, axis=1)

    ### Find location of biggest jumps/falls.
    ###Top and Bottom
    peaks, _ = find_peaks(countRow, distance=15)
    HeightTop=abs(np.diff(countRow[peaks][peaks<hh//5]))
    HeightBtm=abs(np.diff(countRow[peaks][peaks>4*hh//5]))
    max1Height=np.sort(HeightTop)[-1]
    max2Height=np.sort(HeightBtm)[-1]
    X=peaks[ : -1][abs(np.diff(countRow[peaks]))==max1Height][0]
    Y=peaks[ : -1][abs(np.diff(countRow[peaks]))==max2Height][0]
    Top=min([X,Y])
    Btm=max([X,Y])

    ###Left and Right
    peaks, _ = find_peaks(countCol, distance=15)
    HeightLeft=abs(np.diff(countCol[peaks][peaks<ww//5]))
    HeightRight=abs(np.diff(countCol[peaks][peaks>4*ww//5]))
    max1Height=np.sort(HeightLeft)[-1]
    max2Height=np.sort(HeightRight)[-1]
    V=peaks[ : -1][abs(np.diff(countCol[peaks]))==max1Height][0]
    Z=peaks[ : -1][abs(np.diff(countCol[peaks]))==max2Height][0]
    Left=min([V,Z])
    Right=max([V,Z])

    cropped=img[Top:Btm, Left:Right] 
    #cv2.imshow("Result", cropped)
    #cv2.waitKey(0)
    
    #Code for cutting image Side-by-Side
    # read image+crop image
    crop_img=img[Top:Btm, Left:Right]
    HH, WW = crop_img.shape[:2]
    # convert to grayscale
    gray = cv2.cvtColor(crop_img,cv2.COLOR_BGR2GRAY)
    # threshold gray image
    thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

    # count number of non-zero pixels in each column and row. 
    countCol = np.count_nonzero(thresh, axis=0)
    countRow = np.count_nonzero(thresh, axis=1)

    ### This finds the height of the lowest valley
    peaks, _ = find_peaks(-countCol, distance=15)
    maxHeight=np.sort(abs(np.diff(countCol[peaks][(peaks<4*WW//7) & (peaks>3*WW//7)])))[-1]
    Border=peaks[ : -1][abs(np.diff(countCol[peaks]))==maxHeight][0]

    ### loop over contours and get bounding boxes and ycenter and draw horizontal line at ycenter
    result = crop_img.copy()
    LeftImage=result[0:HH,0:Border]
    RighImage=result[0:HH,Border:WW]
    #cv2.imshow("LeftImage", LeftImage)
    #cv2.imshow("RightImage", RighImage)
    #cv2.waitKey(0)

    return(list((LeftImage,RighImage)))

# %% [markdown]
# Code 2: Define Years

# %%
Year=1937

# %% [markdown]
# Code 3: We need to create a seperate directory for each page of the archived copy.
# Check the starting and ending page of the staff directory and define a variable with the numbers.

# %%
StrPage=51
EndPage=300

#Set directory path
for Num in range(StrPage,EndPage):
    try:
        print(Num)
        Righ=Split("{:03d}".format(Num))[1]
        Left=Split("{:03d}".format(Num))[0]

        Page="Page"+"{:03d}".format(2*(Num-StrPage))
        path2 = os.path.join(save_path, Page)
        print(path2+"\\"+Page+".jpg")
        cv2.imwrite(path2+"\\"+Page+".jpg", Righ)

        Page="Page"+"{:03d}".format(2*(Num-StrPage)+1)
        path2 = os.path.join(save_path, Page)
        print(path2+"\\"+Page+".jpg")
        cv2.imwrite(path2+"\\"+Page+".jpg", Left)
    except:
        print("Error at Page " +str(Num))
        continue
# Out:
# 51
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page000\Page000.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page001\Page001.jpg
# 52
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page002\Page002.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page003\Page003.jpg
# 53
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page004\Page004.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page005\Page005.jpg
# 54
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page006\Page006.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page007\Page007.jpg
# 55
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page008\Page008.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page009\Page009.jpg
# 56
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page010\Page010.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page011\Page011.jpg
# 57
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page012\Page012.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page013\Page013.jpg
# 58
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page014\Page014.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page015\Page015.jpg
# 59
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page016\Page016.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page017\Page017.jpg
# 60
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page018\Page018.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page019\Page019.jpg
# 61
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page020\Page020.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page021\Page021.jpg
# 62
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page022\Page022.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page023\Page023.jpg
# 63
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page024\Page024.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page025\Page025.jpg
# 64
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page026\Page026.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page027\Page027.jpg
# 65
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page028\Page028.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page029\Page029.jpg
# 66
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page030\Page030.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page031\Page031.jpg
# 67
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page032\Page032.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page033\Page033.jpg
# 68
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page034\Page034.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page035\Page035.jpg
# 69
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page036\Page036.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page037\Page037.jpg
# 70
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page038\Page038.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page039\Page039.jpg
# 71
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page040\Page040.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page041\Page041.jpg
# 72
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page042\Page042.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page043\Page043.jpg
# 73
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page044\Page044.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page045\Page045.jpg
# 74
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page046\Page046.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page047\Page047.jpg
# 75
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page048\Page048.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page049\Page049.jpg
# 76
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page050\Page050.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page051\Page051.jpg
# 77
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page052\Page052.jpg
# C:\Users\yuyaa.LAPTOP-UEQT9ACJ\Box\Tokyo_Jobs\Raw_Data\Splited\1937\Page053\Page053.jpg
# 78
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-2dcdbd03cf63> in <module>
#       5     try:
#       6         print(Num)
# ----> 7         Righ=Split("{:03d}".format(Num))[1]
#       8         Left=Split("{:03d}".format(Num))[0]
#       9
#
# <ipython-input-1-f2d6e65766ec> in Split(Page)
#      50     HH, WW = crop_img.shape[:2]
#      51     # convert to grayscale
# ---> 52     gray = cv2.cvtColor(crop_img,cv2.COLOR_BGR2GRAY)
#      53     # threshold gray image
#      54     thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-c2l3r8zm\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
img = cv2.imread(path+"Page"+Page+".jpg")
hh, ww = img.shape[:2]
# convert to grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# threshold gray image
thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

# count number of non-zero pixels in each row. 
countCol = np.count_nonzero(thresh, axis=0)
countRow = np.count_nonzero(thresh, axis=1)
